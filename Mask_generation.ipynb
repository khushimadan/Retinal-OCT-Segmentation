# %%
import scipy.io as sio

mat_path = "Farsiu_Ophthalmology_2013_Control_Subject_1001.mat"
data = sio.loadmat(mat_path)

print(data.keys())
for k, v in data.items():
    if isinstance(v, np.ndarray):
        print(k, v.shape)
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'images', 'layerMaps', 'Age'])
# images (512, 1000, 100)
# layerMaps (100, 1000, 3)
# Age (1, 1)

# %%
# running for one failed file. downloaded again
# binary masks for cnn + graph cut (single file version)

import os
import numpy as np
import scipy.io
from PIL import Image
from skimage import img_as_ubyte

# === INPUTS: change these ===
mat_path = "Farsiu_Ophthalmology_2013_AMD_Subject_1257.mat"  
out_dir = "AMD_masks_new"  # output folder
os.makedirs(out_dir, exist_ok=True)

# ---- helper functions ----
def interp_nan(arr):
    """1D linear interpolation for NaN values in boundary arrays"""
    idx = np.arange(arr.size)
    good = np.isfinite(arr)
    if good.sum() == 0:
        return np.zeros_like(arr)
    return np.interp(idx, idx[good], arr[good])

def boundaries_to_mask(boundaries, H):
    """Convert top & bottom boundaries into a binary mask (retina=255, background=0)"""
    W, n_bounds = boundaries.shape
    mask = np.zeros((H, W), dtype=np.uint8)
    top = np.round(boundaries[:, 0]).astype(int)
    bottom = np.round(boundaries[:, -1]).astype(int)
    for x in range(W):
        y1 = np.clip(top[x], 0, H-1)
        y2 = np.clip(bottom[x], 0, H-1)
        if y2 <= y1:  # fix inverted cases
            y1, y2 = min(y1, y2), max(y1, y2)
        mask[y1:y2+1, x] = 255
    return mask

def process_mat(mat_path, out_dir):
    try:
        mat = scipy.io.loadmat(mat_path, squeeze_me=True, struct_as_record=False)
    except Exception as e:
        print(f"❌ Failed to read {mat_path}: {e}")
        return False  # failed

    if "images" not in mat or "layerMaps" not in mat:
        print(f"⚠️ Skipping {mat_path}, keys not found")
        return False  # skipped

    images = mat["images"]       # (H, W, N_slices)
    layerMaps = mat["layerMaps"] # (N_slices, W, 3)
    H, W, N = images.shape
    subj_name = os.path.splitext(os.path.basename(mat_path))[0]

    for s in range(N):
        img = images[:, :, s]
        b = layerMaps[s]  # (W, 3)

        if not np.isfinite(b).any():
            continue  # skip empty slice

        # interpolate NaNs
        for j in range(b.shape[1]):
            if not np.isfinite(b[:, j]).all():
                b[:, j] = interp_nan(b[:, j])

        # normalize image
        img_norm = img_as_ubyte((img - img.min()) / (img.max() - img.min() + 1e-8))

        # save image
        base = f"{subj_name}_slice_{s:03d}"
        img_out = os.path.join(out_dir, base + "_img.png")
        Image.fromarray(img_norm).save(img_out)

        # save mask
        mask = boundaries_to_mask(b, H)
        mask_out = os.path.join(out_dir, base + "_mask.png")
        Image.fromarray(mask).save(mask_out)

        # save boundaries
        np.save(os.path.join(out_dir, base + "_bounds.npy"), b.astype(np.float32))

    print(f"✅ Processed {mat_path}")
    return True


# ---- run for a single file ----
print(f"Processing single file: {mat_path}")
ok = process_mat(mat_path, out_dir)

if ok:
    print("🎉 Done! Outputs saved in:", out_dir)
else:
    print("⚠️ Failed to process file.")
# Out:
# Processing single file: Farsiu_Ophthalmology_2013_AMD_Subject_1257.mat
# ✅ Processed Farsiu_Ophthalmology_2013_AMD_Subject_1257.mat
# 🎉 Done! Outputs saved in: AMD_masks_new

# %%
import os, glob
import numpy as np
import scipy.io
from PIL import Image
from skimage import img_as_ubyte

# === INPUTS ===
mat_dir = "Normal"       # folder with .mat files
out_dir = "Multiclass_normal"  # output folder for multiclass masks
os.makedirs(out_dir, exist_ok=True)

# ---- helper functions ----
def interp_nan(arr):
    """1D linear interpolation for NaN values in boundary arrays"""
    idx = np.arange(arr.size)
    good = np.isfinite(arr)
    if good.sum() == 0:
        return np.zeros_like(arr)
    return np.interp(idx, idx[good], arr[good])

def boundaries_to_multiclass_mask(boundaries, H):
    """
    Convert boundaries into a multi-class mask.
    boundaries: shape (W, n_bounds)
    mask values: 0=background, 1..n_classes = layer regions
    """
    W, n_bounds = boundaries.shape
    mask = np.zeros((H, W), dtype=np.uint8)

    # round and clip each boundary
    b = np.zeros_like(boundaries, dtype=int)
    for j in range(n_bounds):
        b[:, j] = np.clip(np.round(boundaries[:, j]).astype(int), 0, H-1)

    # fill regions between boundaries with increasing class index
    for x in range(W):
        y_prev = 0
        for j in range(n_bounds):
            y_curr = b[x, j]
            if y_curr < y_prev:  # ensure correct order
                y_curr = y_prev
            mask[y_prev:y_curr, x] = j + 1   # class labels start at 1
            y_prev = y_curr
        mask[y_prev:H, x] = n_bounds + 1     # last region = last class

    return mask

def process_mat(mat_path, out_dir):
    mat = scipy.io.loadmat(mat_path, squeeze_me=True, struct_as_record=False)
    if "images" not in mat or "layerMaps" not in mat:
        print(f"Skipping {mat_path}, keys not found")
        return
    
    images = mat["images"]       # (H, W, N_slices)
    layerMaps = mat["layerMaps"] # (N_slices, W, 3)
    H, W, N = images.shape
    subj_name = os.path.splitext(os.path.basename(mat_path))[0]

    for s in range(N):
        img = images[:,:,s]
        b = layerMaps[s]  # (W, 3)

        if not np.isfinite(b).any():
            continue  # skip empty slice

        # interpolate NaNs in each boundary column
        for j in range(b.shape[1]):
            if not np.isfinite(b[:,j]).all():
                b[:,j] = interp_nan(b[:,j])

        # normalize image to 0..255
        img_norm = img_as_ubyte((img - img.min())/(img.max()-img.min() + 1e-8))

        # save image
        base = f"{subj_name}_slice_{s:03d}"
        img_out = os.path.join(out_dir, base + "_img.png")
        Image.fromarray(img_norm).save(img_out)

        # save multi-class mask
        mask = boundaries_to_multiclass_mask(b, H)

        # --- scale for visualization (each class has unique gray intensity) ---
        mask_vis = (mask * (255 // mask.max())).astype(np.uint8)

        mask_out = os.path.join(out_dir, base + "_mask.png")
        Image.fromarray(mask_vis).save(mask_out)

        # save raw mask (true class labels, useful for training)
        np.save(os.path.join(out_dir, base + "_mask.npy"), mask.astype(np.uint8))

        # save raw boundary arrays for metrics
        np.save(os.path.join(out_dir, base + "_bounds.npy"), b.astype(np.float32))

    print(f"Processed {mat_path}")

# ---- run on all .mat files ----
mat_files = glob.glob(os.path.join(mat_dir, "*.mat"))
print(f"Found {len(mat_files)} .mat files")

for m in mat_files:
    process_mat(m, out_dir)

print("✅ All done! Multi-class processed data saved in:", out_dir)
# Out:
# Found 115 .mat files
# Processed Normal/Farsiu_Ophthalmology_2013_Control_Subject_1007.mat
# Processed Normal/Farsiu_Ophthalmology_2013_Control_Subject_1013.mat
# Processed Normal/Farsiu_Ophthalmology_2013_Control_Subject_1012.mat
# Processed Normal/Farsiu_Ophthalmology_2013_Control_Subject_1006.mat
# Processed Normal/Farsiu_Ophthalmology_2013_Control_Subject_1038.mat
# Processed Normal/Farsiu_Ophthalmology_2013_Control_Subject_1010.mat
# Processed Normal/Farsiu_Ophthalmology_2013_Control_Subject_1004.mat
# Processed Normal/Farsiu_Ophthalmology_2013_Control_Subject_1005.mat
# Processed Normal/Farsiu_Ophthalmology_2013_Control_Subject_1011.mat
# Processed Normal/Farsiu_Ophthalmology_2013_Control_Subject_1039.mat
# Processed Normal/Farsiu_Ophthalmology_2013_Control_Subject_1015.mat
# Processed Normal/Farsiu_Ophthalmology_2013_Control_Subject_1001.mat
# Processed Normal/Farsiu_Ophthalmology_2013_Control_Subject_1029.mat
# Processed Normal/Farsiu_Ophthalmology_2013_Control_Subject_1028.mat
# Processed Normal/Farsiu_Ophthalmology_2013_Control_Subject_1014.mat
# Processed Normal/Farsiu_Ophthalmology_2013_Control_Subject_1002.mat
# Processed Normal/Farsiu_Ophthalmology_2013_Control_Subject_1016.mat
# Processed Normal/Farsiu_Ophthalmology_2013_Control_Subject_1017.mat
# Processed Normal/Farsiu_Ophthalmology_2013_Control_Subject_1003.mat
# Processed Normal/Farsiu_Ophthalmology_2013_Control_Subject_1110.mat
# Processed Normal/Farsiu_Ophthalmology_2013_Control_Subject_1104.mat
# Processed Normal/Farsiu_Ophthalmology_2013_Control_Subject_1058.mat
# Processed Normal/Farsiu_Ophthalmology_2013_Control_Subject_1064.mat
# Processed Normal/Farsiu_Ophthalmology_2013_Control_Subject_1070.mat
# Processed Normal/Farsiu_Ophthalmology_2013_Control_Subject_1071.mat
# Processed Normal/Farsiu_Ophthalmology_2013_Control_Subject_1065.mat
# Processed Normal/Farsiu_Ophthalmology_2013_Control_Subject_1059.mat
# Processed Normal/Farsiu_Ophthalmology_2013_Control_Subject_1105.mat
# Processed Normal/Farsiu_Ophthalmology_2013_Control_Subject_1111.mat
# Processed Normal/Farsiu_Ophthalmology_2013_Control_Subject_1107.mat
# Processed Normal/Farsiu_Ophthalmology_2013_Control_Subject_1113.mat
# Processed Normal/Farsiu_Ophthalmology_2013_Control_Subject_1073.mat
# Processed Normal/Farsiu_Ophthalmology_2013_Control_Subject_1067.mat
# Processed Normal/Farsiu_Ophthalmology_2013_Control_Subject_1098.mat
# Processed Normal/Farsiu_Ophthalmology_2013_Control_Subject_1099.mat
# Processed Normal/Farsiu_Ophthalmology_2013_Control_Subject_1066.mat
# Processed Normal/Farsiu_Ophthalmology_2013_Control_Subject_1072.mat
# Processed Normal/Farsiu_Ophthalmology_2013_Control_Subject_1112.mat
# Processed Normal/Farsiu_Ophthalmology_2013_Control_Subject_1106.mat
# Processed Normal/Farsiu_Ophthalmology_2013_Control_Subject_1102.mat
# Processed Normal/Farsiu_Ophthalmology_2013_Control_Subject_1076.mat
# Processed Normal/Farsiu_Ophthalmology_2013_Control_Subject_1062.mat
# Processed Normal/Farsiu_Ophthalmology_2013_Control_Subject_1089.mat
# Processed Normal/Farsiu_Ophthalmology_2013_Control_Subject_1088.mat
# Processed Normal/Farsiu_Ophthalmology_2013_Control_Subject_1063.mat
# Processed Normal/Farsiu_Ophthalmology_2013_Control_Subject_1077.mat
# Processed Normal/Farsiu_Ophthalmology_2013_Control_Subject_1103.mat
# Processed Normal/Farsiu_Ophthalmology_2013_Control_Subject_1115.mat
# Processed Normal/Farsiu_Ophthalmology_2013_Control_Subject_1101.mat
# Processed Normal/Farsiu_Ophthalmology_2013_Control_Subject_1061.mat
# Processed Normal/Farsiu_Ophthalmology_2013_Control_Subject_1075.mat
# Processed Normal/Farsiu_Ophthalmology_2013_Control_Subject_1049.mat
# Processed Normal/Farsiu_Ophthalmology_2013_Control_Subject_1048.mat
# Processed Normal/Farsiu_Ophthalmology_2013_Control_Subject_1074.mat
# Processed Normal/Farsiu_Ophthalmology_2013_Control_Subject_1060.mat
# Processed Normal/Farsiu_Ophthalmology_2013_Control_Subject_1100.mat
# Processed Normal/Farsiu_Ophthalmology_2013_Control_Subject_1114.mat
# Processed Normal/Farsiu_Ophthalmology_2013_Control_Subject_1079.mat
# Processed Normal/Farsiu_Ophthalmology_2013_Control_Subject_1045.mat
# Processed Normal/Farsiu_Ophthalmology_2013_Control_Subject_1051.mat
# Processed Normal/Farsiu_Ophthalmology_2013_Control_Subject_1086.mat
# Processed Normal/Farsiu_Ophthalmology_2013_Control_Subject_1092.mat
# Processed Normal/Farsiu_Ophthalmology_2013_Control_Subject_1093.mat
# Processed Normal/Farsiu_Ophthalmology_2013_Control_Subject_1087.mat
# Processed Normal/Farsiu_Ophthalmology_2013_Control_Subject_1050.mat
# Processed Normal/Farsiu_Ophthalmology_2013_Control_Subject_1044.mat
# Processed Normal/Farsiu_Ophthalmology_2013_Control_Subject_1078.mat
# Processed Normal/Farsiu_Ophthalmology_2013_Control_Subject_1052.mat
# Processed Normal/Farsiu_Ophthalmology_2013_Control_Subject_1046.mat
# Processed Normal/Farsiu_Ophthalmology_2013_Control_Subject_1091.mat
# Processed Normal/Farsiu_Ophthalmology_2013_Control_Subject_1085.mat
# Processed Normal/Farsiu_Ophthalmology_2013_Control_Subject_1084.mat
# Processed Normal/Farsiu_Ophthalmology_2013_Control_Subject_1090.mat
# Processed Normal/Farsiu_Ophthalmology_2013_Control_Subject_1047.mat
# Processed Normal/Farsiu_Ophthalmology_2013_Control_Subject_1053.mat
# Processed Normal/Farsiu_Ophthalmology_2013_Control_Subject_1057.mat
# Processed Normal/Farsiu_Ophthalmology_2013_Control_Subject_1043.mat
# Processed Normal/Farsiu_Ophthalmology_2013_Control_Subject_1094.mat
# Processed Normal/Farsiu_Ophthalmology_2013_Control_Subject_1080.mat
# Processed Normal/Farsiu_Ophthalmology_2013_Control_Subject_1081.mat
# Processed Normal/Farsiu_Ophthalmology_2013_Control_Subject_1095.mat
# Processed Normal/Farsiu_Ophthalmology_2013_Control_Subject_1042.mat
# Processed Normal/Farsiu_Ophthalmology_2013_Control_Subject_1056.mat
# Processed Normal/Farsiu_Ophthalmology_2013_Control_Subject_1108.mat
# Processed Normal/Farsiu_Ophthalmology_2013_Control_Subject_1040.mat
# Processed Normal/Farsiu_Ophthalmology_2013_Control_Subject_1054.mat
# Processed Normal/Farsiu_Ophthalmology_2013_Control_Subject_1068.mat
# Processed Normal/Farsiu_Ophthalmology_2013_Control_Subject_1083.mat
# Processed Normal/Farsiu_Ophthalmology_2013_Control_Subject_1097.mat
# Processed Normal/Farsiu_Ophthalmology_2013_Control_Subject_1096.mat
# Processed Normal/Farsiu_Ophthalmology_2013_Control_Subject_1082.mat
# Processed Normal/Farsiu_Ophthalmology_2013_Control_Subject_1069.mat
# Processed Normal/Farsiu_Ophthalmology_2013_Control_Subject_1055.mat
# Processed Normal/Farsiu_Ophthalmology_2013_Control_Subject_1041.mat
# Processed Normal/Farsiu_Ophthalmology_2013_Control_Subject_1109.mat
# Processed Normal/Farsiu_Ophthalmology_2013_Control_Subject_1026.mat
# Processed Normal/Farsiu_Ophthalmology_2013_Control_Subject_1032.mat
# Processed Normal/Farsiu_Ophthalmology_2013_Control_Subject_1033.mat
# Processed Normal/Farsiu_Ophthalmology_2013_Control_Subject_1027.mat
# Processed Normal/Farsiu_Ophthalmology_2013_Control_Subject_1019.mat
# Processed Normal/Farsiu_Ophthalmology_2013_Control_Subject_1031.mat
# Processed Normal/Farsiu_Ophthalmology_2013_Control_Subject_1025.mat
# Processed Normal/Farsiu_Ophthalmology_2013_Control_Subject_1024.mat
# Processed Normal/Farsiu_Ophthalmology_2013_Control_Subject_1030.mat
# Processed Normal/Farsiu_Ophthalmology_2013_Control_Subject_1018.mat
# Processed Normal/Farsiu_Ophthalmology_2013_Control_Subject_1034.mat
# Processed Normal/Farsiu_Ophthalmology_2013_Control_Subject_1020.mat
# Processed Normal/Farsiu_Ophthalmology_2013_Control_Subject_1008.mat
# Processed Normal/Farsiu_Ophthalmology_2013_Control_Subject_1009.mat
# Processed Normal/Farsiu_Ophthalmology_2013_Control_Subject_1021.mat
# Processed Normal/Farsiu_Ophthalmology_2013_Control_Subject_1035.mat
# Processed Normal/Farsiu_Ophthalmology_2013_Control_Subject_1023.mat
# Processed Normal/Farsiu_Ophthalmology_2013_Control_Subject_1037.mat
# Processed Normal/Farsiu_Ophthalmology_2013_Control_Subject_1036.mat
# Processed Normal/Farsiu_Ophthalmology_2013_Control_Subject_1022.mat
# ✅ All done! Multi-class processed data saved in: Multiclass_normal

# %%
import os, glob
import numpy as np
import scipy.io
from PIL import Image
from skimage import img_as_ubyte

# === INPUTS ===
mat_dir = "AMD"       # folder with .mat files
out_dir = "Multiclass_AMD"  # output folder for multiclass masks
os.makedirs(out_dir, exist_ok=True)

# ---- helper functions ----
def interp_nan(arr):
    """1D linear interpolation for NaN values in boundary arrays"""
    idx = np.arange(arr.size)
    good = np.isfinite(arr)
    if good.sum() == 0:
        return np.zeros_like(arr)
    return np.interp(idx, idx[good], arr[good])

def boundaries_to_multiclass_mask(boundaries, H):
    """
    Convert boundaries into a multi-class mask.
    boundaries: shape (W, n_bounds)
    mask values: 0=background, 1..n_classes = layer regions
    """
    W, n_bounds = boundaries.shape
    mask = np.zeros((H, W), dtype=np.uint8)

    # round and clip each boundary
    b = np.zeros_like(boundaries, dtype=int)
    for j in range(n_bounds):
        b[:, j] = np.clip(np.round(boundaries[:, j]).astype(int), 0, H-1)

    # fill regions between boundaries with increasing class index
    for x in range(W):
        y_prev = 0
        for j in range(n_bounds):
            y_curr = b[x, j]
            if y_curr < y_prev:  # ensure correct order
                y_curr = y_prev
            mask[y_prev:y_curr, x] = j + 1   # class labels start at 1
            y_prev = y_curr
        mask[y_prev:H, x] = n_bounds + 1     # last region = last class

    return mask

def process_mat(mat_path, out_dir):
    mat = scipy.io.loadmat(mat_path, squeeze_me=True, struct_as_record=False)
    if "images" not in mat or "layerMaps" not in mat:
        print(f"Skipping {mat_path}, keys not found")
        return
    
    images = mat["images"]       # (H, W, N_slices)
    layerMaps = mat["layerMaps"] # (N_slices, W, 3)
    H, W, N = images.shape
    subj_name = os.path.splitext(os.path.basename(mat_path))[0]

    for s in range(N):
        img = images[:,:,s]
        b = layerMaps[s]  # (W, 3)

        if not np.isfinite(b).any():
            continue  # skip empty slice

        # interpolate NaNs in each boundary column
        for j in range(b.shape[1]):
            if not np.isfinite(b[:,j]).all():
                b[:,j] = interp_nan(b[:,j])

        # normalize image to 0..255
        img_norm = img_as_ubyte((img - img.min())/(img.max()-img.min() + 1e-8))

        # save image
        base = f"{subj_name}_slice_{s:03d}"
        img_out = os.path.join(out_dir, base + "_img.png")
        Image.fromarray(img_norm).save(img_out)

        # save multi-class mask
        mask = boundaries_to_multiclass_mask(b, H)

        # --- scale for visualization (each class has unique gray intensity) ---
        mask_vis = (mask * (255 // mask.max())).astype(np.uint8)

        mask_out = os.path.join(out_dir, base + "_mask.png")
        Image.fromarray(mask_vis).save(mask_out)

        # save raw mask (true class labels, useful for training)
        np.save(os.path.join(out_dir, base + "_mask.npy"), mask.astype(np.uint8))

        # save raw boundary arrays for metrics
        np.save(os.path.join(out_dir, base + "_bounds.npy"), b.astype(np.float32))

    print(f"Processed {mat_path}")

# ---- run on all .mat files ----
mat_files = glob.glob(os.path.join(mat_dir, "*.mat"))
print(f"Found {len(mat_files)} .mat files")

for m in mat_files:
    process_mat(m, out_dir)

print("✅ All done! Multi-class processed data saved in:", out_dir)
# Out:
# Found 269 .mat files
# Processed AMD/Farsiu_Ophthalmology_2013_AMD_Subject_1178.mat
# Processed AMD/Farsiu_Ophthalmology_2013_AMD_Subject_1150.mat
# Processed AMD/Farsiu_Ophthalmology_2013_AMD_Subject_1144.mat
# Processed AMD/Farsiu_Ophthalmology_2013_AMD_Subject_1193.mat
# Processed AMD/Farsiu_Ophthalmology_2013_AMD_Subject_1187.mat
# Processed AMD/Farsiu_Ophthalmology_2013_AMD_Subject_1226.mat
# Processed AMD/Farsiu_Ophthalmology_2013_AMD_Subject_1232.mat
# Processed AMD/Farsiu_Ophthalmology_2013_AMD_Subject_1018.mat
# Processed AMD/Farsiu_Ophthalmology_2013_AMD_Subject_1024.mat
# Processed AMD/Farsiu_Ophthalmology_2013_AMD_Subject_1030.mat
# Processed AMD/Farsiu_Ophthalmology_2013_AMD_Subject_1031.mat
# Processed AMD/Farsiu_Ophthalmology_2013_AMD_Subject_1025.mat
# Processed AMD/Farsiu_Ophthalmology_2013_AMD_Subject_1019.mat
# Processed AMD/Farsiu_Ophthalmology_2013_AMD_Subject_1233.mat
# Processed AMD/Farsiu_Ophthalmology_2013_AMD_Subject_1227.mat
# Processed AMD/Farsiu_Ophthalmology_2013_AMD_Subject_1186.mat
# Processed AMD/Farsiu_Ophthalmology_2013_AMD_Subject_1192.mat
# Processed AMD/Farsiu_Ophthalmology_2013_AMD_Subject_1145.mat
# Processed AMD/Farsiu_Ophthalmology_2013_AMD_Subject_1151.mat
# Processed AMD/Farsiu_Ophthalmology_2013_AMD_Subject_1179.mat
# Processed AMD/Farsiu_Ophthalmology_2013_AMD_Subject_1147.mat
# Processed AMD/Farsiu_Ophthalmology_2013_AMD_Subject_1153.mat
# Processed AMD/Farsiu_Ophthalmology_2013_AMD_Subject_1184.mat
# Processed AMD/Farsiu_Ophthalmology_2013_AMD_Subject_1190.mat
# Processed AMD/Farsiu_Ophthalmology_2013_AMD_Subject_1219.mat
# Processed AMD/Farsiu_Ophthalmology_2013_AMD_Subject_1231.mat
# Processed AMD/Farsiu_Ophthalmology_2013_AMD_Subject_1225.mat
# Processed AMD/Farsiu_Ophthalmology_2013_AMD_Subject_1033.mat
# Processed AMD/Farsiu_Ophthalmology_2013_AMD_Subject_1027.mat
# Processed AMD/Farsiu_Ophthalmology_2013_AMD_Subject_1026.mat
# Processed AMD/Farsiu_Ophthalmology_2013_AMD_Subject_1032.mat
# Processed AMD/Farsiu_Ophthalmology_2013_AMD_Subject_1224.mat
# Processed AMD/Farsiu_Ophthalmology_2013_AMD_Subject_1230.mat
# Processed AMD/Farsiu_Ophthalmology_2013_AMD_Subject_1218.mat
# Processed AMD/Farsiu_Ophthalmology_2013_AMD_Subject_1191.mat

# %%
from PIL import Image
import numpy as np

# Load the mask
mask_path = "Multiclass_normal/Farsiu_Ophthalmology_2013_Control_Subject_1001_slice_011_mask.png"
mask = Image.open(mask_path).convert("L")   # ensure grayscale
mask_np = np.array(mask)

# Check unique pixel values
unique_vals = np.unique(mask_np)
print("Unique pixel values in mask:", unique_vals)
# Out:
# Unique pixel values in mask: [ 63 126 189 252]
